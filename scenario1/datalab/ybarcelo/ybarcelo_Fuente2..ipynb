# %% [markdown]
# # EDA - Fuente de datos 2
# ## Plan Anual de Adquisiones - Secop II

# %% [markdown]
# **Importar librerías.**

# %%
# Load Packages
import os,sys
import pandas as pd
import numpy as np
from datetime import datetime

# This line is needed to display plots inline in Jupyter Notebook
# %matplotlib inline

# Required for basic python plotting functionality
import matplotlib.pyplot as plt

# Required for formatting dates later in the case
import datetime
import matplotlib.dates as mdates

# Required to display image inline
from IPython.display import Image

# Advanced plotting functionality with seaborn
import seaborn as sns
sns.set(style="whitegrid") # can set style depending on how you'd like it to look

# %% [markdown]
# **Importar la base de datos (CSV).**

# %%
df = pd.read_csv (r'C:\Users\ybarcelo\Desktop\Yalitza Barcelo\EAFIT\PROYECTO INTEGRADOR\Plan_Anual_de_Adquisiciones_-_SECOP_II.csv')
df.head()
df.head(5)
# Out:
#    Anno Identificador PAA                                            Entidad  \
# 0  2018    CO1.APP.361029  COMANDO DE RECLUTAMIENTO Y CONTROL RESERVAS DE...
# 1  2019    CO1.APP.525808                     SUPERINTENDENCIA DE TRANSPORTE
# 2  2019    CO1.APP.460110                                       FONAM - DTAN
# 3  2018    CO1.APP.338501                           ESAP TERRITORIAL BOLIVAR
# 4  2018    CO1.APP.324303                             GRUPO AÉREO DEL CARIBE
#
#          NIT  Localización                      DescripcionUbicacion  \
# 0  800130643   CO-DC-11001                Distrito Capital de Bogotá
# 1  800170433   CO-DC-11001                Distrito Capital de Bogotá
# 2  901037393  CO-SAN-68001                                 Santander
# 3  800248529  CO-BOL-13001                                   Bolívar
# 4  800141634  CO-SAP-88001  San Andrés, Providencia y Santa Catalina
#
#                                        Mision/Vision  \
# ...

# %%
df.shape
# Out:
# (863969, 29)

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 863964     True
# 863965     True
# 863966     True
# 863967     True
# 863968     True
# Length: 863969, dtype: bool

# %%
df = df.drop_duplicates()
df
# Out:
#         Anno Identificador PAA  \
# 0       2018    CO1.APP.361029
# 1       2019    CO1.APP.525808
# 2       2019    CO1.APP.460110
# 3       2018    CO1.APP.338501
# 4       2018    CO1.APP.324303
# ...      ...               ...
# 863942  2019    CO1.APP.538602
# 863943  2019    CO1.APP.531105
# 863944  2019    CO1.APP.570615
# 863945  2018    CO1.APP.349503
# 863949  2018    CO1.APP.353312
#
#                                                   Entidad        NIT  \
# 0       COMANDO DE RECLUTAMIENTO Y CONTROL RESERVAS DE...  800130643
# 1                          SUPERINTENDENCIA DE TRANSPORTE  800170433
# 2                                            FONAM - DTAN  901037393
# 3                                ESAP TERRITORIAL BOLIVAR  800248529
# 4                                  GRUPO AÉREO DEL CARIBE  800141634
# ...                                                   ...        ...
# 863942                         INSTITUTO NACIONAL DE VIAS  800215807
# ...

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 863942    False
# 863943    False
# 863944    False
# 863945    False
# 863949    False
# Length: 330264, dtype: bool

# %%
nitsunicos=df['NIT'].unique()
print(df['NIT'].unique())
print(type(df['NIT'].unique()))
# Out:
# [ 800130643  800170433  901037393  800248529  800141634  899999118
#   830040256  890801052  800215807  813001834  900971006  800250062
#   899999102  900959051  900973540 8002469532  830039670 8906800622
#   900002583  811010070  890201900  899999061 8999990619 8300396705
#  9005077411  800113389  834000421 8301259969  899999316  800140985
#   860030197  899999333  810001377  890907106 8200009822  899999090
#   899999004  800140603  830115395  800130681  860061099  800141633
#   800141638  830115226  811010111  800117519  899999282  830002634
#   900413030  800141642  899999028  800117522  800141624  800130646
#   822001371  800150861  800114312  890201235  900475780  891410354
#   800112806  899999294  900517646  800131039  900463725  899999162
#   891180268  819000759  900457461  899999001  819001482  890905211
#   800176089  800154275  830114475  900788066  900127054  800230729
#   810001096  817001031  830034348  899999048  899999020  899999421
# ...

# %%
nitsunicos.shape
# Out:
# (941,)

# %%
dfsinduplicados=df.drop_duplicates(['Anno', 'NIT','Mision/Vision','Perspectiva Estrategica'], keep='last')

# %%
dfsinduplicados.to_csv('dataprrr.csv')

# %%
dfsinduplicados.shape
# Out:
# (2085, 29)

# %%
dfgrupo=dfsinduplicados.groupby(by=['NIT','Anno','Entidad','Mision/Vision','Perspectiva Estrategica']).mean()
dfgrupo.sort_values(by='Anno', ascending=False, na_position='first')
# Out:
#                                                                                                                                                                           Presupuesto Menor Cuantia  \
# NIT        Anno Entidad                                            Mision/Vision                                      Perspectiva Estrategica
# 9013620904 2020 UNIDAD PRESTADORA DE SALUD ATLANTICO               Contribuir a la calidad de vida de nuestros usu... Administración del riesgo financiero, la gestió...                  877803000
# 900336524  2020 REGIONAL DE ASEGURAMIENTO EN SALUD No. 1           MISIÓN\nLa Policía Nacional adopta como Misión ... MEGA\nLa Policía Nacional acoge como Meta Grand...                  877803000
# 838000330  2020 MINISTERIO DEL TRABAJO DIRECCION TERRITORIAL DE... MISIÓN Formular, adoptar y orientar la política... El Ministerio del Trabajo se dispone a ejecutar...                  877803000
# ...

# %%
dfgrupo.head()
# Out:
#                                                                                                                                                              Presupuesto Menor Cuantia  \
# NIT       Anno Entidad                                Mision/Vision                                      Perspectiva Estrategica
# 40330032  2019 BARBARA IVONNE LINARES RODRIGUEZ       El municipio de La Macarena será en el 2027 un ... Un Gobierno que responda oportuna y eficienteme...                  231872480
# 88143760  2018 SAID ALONSO PEÑALOZA ANTELIZ           Promover el desarrollo humano y sostenible del ... En el año 2025, El Municipio de Ocaña será una ...                  218747844
# 123456780 2016 NO UTILIZAR                            Misión\nLograr una EDUCACIÓN DE CALIDAD, que fo... Objetivos Misionales\n\nBrindar educación inic...                  689454000
# ...

# %%
##from nltk.corpus import stopwords
import nltk
import pandas as pd
import numpy as np
import re
import codecs
import matplotlib.pyplot as plt
import nltk
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\ybarcelo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True

# %%
# Corpus de NLTK para 'tokenizer' y 'stopwords'
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ybarcelo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ybarcelo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
# Instalar NLTK, PySpark y Stop-Words
# !pip install nltk
# !pip install pyspark
# !pip install stop-words
# Out:
# ...
#   Created wheel for pyspark: filename=pyspark-3.1.1-py2.py3-none-any.whl size=212767609 sha256=5dd985010f366f2dafe40f5c24d6045c6403dbbc6dc040d42f3a76f77bcfe01b
#   Stored in directory: c:\users\ybarcelo\appdata\local\pip\cache\wheels\b3\0e\81\264aeed961e43b9f6ba9ec81c8c540d2d7dccc52c6b51cbf22
# Successfully built pyspark
# ...
#   Created wheel for stop-words: filename=stop_words-2018.7.23-py3-none-any.whl size=32920 sha256=734c3a5793d351689c32e69284d06c8a521850f1da133a5fe5a834099af73c9c
#   Stored in directory: c:\users\ybarcelo\appdata\local\pip\cache\wheels\eb\03\0d\3bd31c983789aeb0b4d5e2ca48590288d9db1586cf5f225062
# Successfully built stop-words
# ...

# %%
# stopwords en NLTK
from nltk.corpus import stopwords
stop_words_nltk = set(stopwords.words('spanish'))
#print("Número de stop words nltk: ",len(stop_words_nltk))
#print(stop_words_nltk)

# %%
def tokensnltk(dfsinduplicados):
  tokens = nltk.word_tokenize(dfsinduplicados)
  tokens = [w.lower() for w in tokens if len(w)>1]
  tokens = [re.sub(r'[^A-Za-z0-9]+','',w) for w in tokens]
  tokens = [w for w in tokens if w not in stop_words_nltk]
  return (tokens)

newdf = tokensnltk(dfsinduplicados)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-7b3bd3cae40a> in <module>
#       6   return (tokens)
#       7
# ----> 8 newdf = tokensnltk(dfsinduplicados)
#
# <ipython-input-36-7b3bd3cae40a> in tokensnltk(dfsinduplicados)
#       1 def tokensnltk(dfsinduplicados):
# ----> 2   tokens = nltk.word_tokenize(dfsinduplicados)
#       3   tokens = [w.lower() for w in tokens if len(w)>1]
#       4   tokens = [re.sub(r'[^A-Za-z0-9]+','',w) for w in tokens]
#       5   tokens = [w for w in tokens if w not in stop_words_nltk]
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\__init__.py in word_tokenize(text, language, preserve_line)
#     127     :type preserve_line: bool
#     128     """
# --> 129     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     130     return [
# ...

# %%
dfsinduplicados.head()
# Out:
#        Anno Identificador PAA  \
# 3198   2018    co  app
# 6497   2017    co  app
# 14182  2020    co  app
# 17152  2017    co  app
# 21682  2019    co  app
#
#                                                  Entidad        NIT  \
# 3198                                 municipio de guepsa  890207790
# 6497   empresa social del estado del municipio de vil...  822002459
# 14182                         alcald a municipal de tota  800012635
# 17152  parques nacionales naturales de colombia   dir...  900005502
# 21682                institucion educativa diversificado  832003903
#
#        Localización        DescripcionUbicacion  \
# 3198   co san                         santander
# 6497   co met                              meta
# 14182  co boy                            boyac
# 17152         co dc  distrito capital de bogot
# 21682  co cun                      cundinamarca
#
#                                            Mision/Vision  \
# ...

# %%
# Convertir el dataset a minúscula, elimina números y urls
dfsinduplicados = dfsinduplicados.apply(lambda x:x.astype(str).str.lower() if(x.dtype=="object") else x)
# Second: Remove URLs, non alphabetic symbols
dfsinduplicados = dfsinduplicados.apply(lambda x:x.astype(str).str.replace('https?://.*',' ') if(x.dtype=="object") else x)        
dfsinduplicados = dfsinduplicados.apply(lambda x:x.astype(str).str.replace('[^a-zA-Z]',' ') if(x.dtype=="object") else x)
pat = r'\b(?:{})\b'.format('|'.join(stop))
dfsinduplicados['Perspectiva_nueva'] = test['Perspectiva Estrategica'].str.replace(pat, '')
dfsinduplicados['Perspectiva_nueva'] = test['Perspectiva_nueva'].str.replace(r'\s+', ' ')
dfsinduplicados.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-4654fdf31a4e> in <module>
#       4 dfsinduplicados = dfsinduplicados.apply(lambda x:x.astype(str).str.replace('https?://.*',' ') if(x.dtype=="object") else x)
#       5 dfsinduplicados = dfsinduplicados.apply(lambda x:x.astype(str).str.replace('[^a-zA-Z]',' ') if(x.dtype=="object") else x)
# ----> 6 pat = r'\b(?:{})\b'.format('|'.join(stop))
#       7 dfsinduplicados['Perspectiva_nueva'] = test['Perspectiva Estrategica'].str.replace(pat, '')
#       8 dfsinduplicados['Perspectiva_nueva'] = test['Perspectiva_nueva'].str.replace(r'\s+', ' ')
#
# NameError: name 'stop' is not defined

# %%
dfsinduplicados.shape
# Out:
# (2085, 29)

# %%
dfsinduplicados.to_csv(r'C:\Users\ybarcelo\Desktop\Yalitza Barcelo\EAFIT\PROYECTO INTEGRADOR\dataprueba.csv')

# %%
reference_list = ['tecnolo','sistem','data'] # Se Colocan las palabras a filtrar

select_data = pd.DataFrame()
for keywords in reference_list:
    select_data = select_data.append(dfsinduplicados[dfsinduplicados['Perspectiva Estrategica'].str.contains(keywords, na=False)])

select_data.head()

# %%
#Obtiene las palabras mas frecuentes
numWords = 20
wordfrequency = dfsinduplicados['Perspectiva Estrategica'].str.split(expand=True).stack().value_counts()
wordfrequency.head(numWords)
